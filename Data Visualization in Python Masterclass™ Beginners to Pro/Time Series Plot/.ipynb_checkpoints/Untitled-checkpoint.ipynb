# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams[]

# %%
df = pd.read_csv('daily-temperature.csv')

# %%
df.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %%
df['Date'].astype(datetime)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-22559bc11891> in <module>
# ----> 1 df['Date'].astype(datetime64)
#
# NameError: name 'datetime64' is not defined

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.set_index('Date', inplace = True)

# %%
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df.plot(color = 'm', figsize = (14,8))
plt.xlabel('Year')
plt.ylabel('Degree')
plt.title('Temp')
# Out:
# Text(0.5, 1.0, 'Temp')

# %%
plt.figure(figsize = (14,8), dpi = 150)
plt.plot(df['Temp'])

# %%
df.plot(style = '.', figsize = (14,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ygr = df.groupby(pd.Grouper(freq = 'Y'))

# %%
ygrkey = ygr.groups.keys()

# %%
years = pd.DataFrame()
for key in ygrkey:
    years[key] = ygr.get_group(key)['Temp'].values

# %%
years.columns = indexs = list(range(1981, 1991))

# %%
years
# Out:
#      1981  1982  1983  1984  1985  1986  1987  1988  1989  1990
# 0    20.7  17.0  18.4  19.5  13.3  12.9  12.3  15.3  14.3  14.8
# 1    17.9  15.0  15.0  17.1  15.2  13.8  13.8  14.3  17.4  13.3
# 2    18.8  13.5  10.9  17.1  13.1  10.6  15.3  13.5  18.5  15.6
# 3    14.6  15.2  11.4  12.0  12.7  12.6  15.6  15.0  16.8  14.5
# 4    15.8  13.0  14.8  11.0  14.6  13.7  16.2  13.6  11.5  14.3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 360  15.5  15.3  13.9  12.2  11.5  14.6  16.2   9.5  13.3  14.0
# 361  13.3  16.3  11.1  12.0  10.8  14.2  14.2  12.9  11.7  13.6
# 362  15.6  15.8  16.1  12.6  12.0  13.2  14.3  12.9  10.4  13.5
# 363  15.2  17.7  20.4  16.0  16.3  11.7  13.3  14.8  14.4  15.7
# 364  17.4  16.3  18.0  16.4  14.4  17.2  16.7  14.1  12.7  13.0
#
# [365 rows x 10 columns]

# %%
years.plot(subplots = True, figsize = (14, 40))
plt.tight_layout()

# %%
plt.matshow(years.T, aspect = 'auto')

# %%
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.plot.hist(bins = 36)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(bins = 36, grid = False, figsize = (12,8))
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')

# %%
df.plot.kde(figsize = (12,8))
# Out:
# <AxesSubplot:ylabel='Density'>
