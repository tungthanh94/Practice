# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2021-01-01', periods = 1000), columns = ['value'])

# %%
df
# Out:
#                value
# 2021-01-01  1.186163
# 2021-01-02 -1.086612
# 2021-01-03  1.261066
# 2021-01-04  1.320362
# 2021-01-05  2.570162
# ...              ...
# 2023-09-23  0.188187
# 2023-09-24  0.762146
# 2023-09-25  0.370078
# 2023-09-26  0.696628
# 2023-09-27 -0.917259
#
# [1000 rows x 1 columns]

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2021-01-01', periods = 1000))

# %%
ts
# Out:
# 2021-01-01   -1.081884
# 2021-01-02    0.918079
# 2021-01-03   -0.680039
# 2021-01-04    0.438112
# 2021-01-05   -0.018259
#                 ...
# 2023-09-23   -0.840217
# 2023-09-24    1.074464
# 2023-09-25   -0.420594
# 2023-09-26    0.013911
# 2023-09-27   -1.052065
# Freq: D, Length: 1000, dtype: float64

# %%
df['value1'] = df['value'].cumsum()

# %%
ts1 = ts.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts1.plot(figsize = (12,10))
# Out:
# <AxesSubplot:>

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(figsize = (14,10))
# Out:
# <AxesSubplot:>

# %%
iris.plot(legend = False, figsize = (12,6), logy = True)
plt.ylim(0, 10)
# Out:
# <ipython-input-15-8339b1816bf4>:2: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0, 10)
# (0.08037456684477631, 10)

# %%
x = iris.drop(['sepal_width','petal_width'], axis  = 1)
x
# Out:
#      sepal_length  petal_length    species
# 0             5.1           1.4     setosa
# 1             4.9           1.4     setosa
# 2             4.7           1.3     setosa
# 3             4.6           1.5     setosa
# 4             5.0           1.4     setosa
# ..            ...           ...        ...
# 145           6.7           5.2  virginica
# 146           6.3           5.0  virginica
# 147           6.5           5.2  virginica
# 148           6.2           5.4  virginica
# 149           5.9           5.1  virginica
#
# [150 rows x 3 columns]

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
y = iris[['sepal_width','petal_width']]

# %%
y
# Out:
#      sepal_width  petal_width
# 0            3.5          0.2
# 1            3.0          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 4            3.6          0.2
# ..           ...          ...
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8
#
# [150 rows x 2 columns]

# %%
ax = x.plot()
y.plot(figsize = (16,10), ax = ax)
# Out:
# <AxesSubplot:>

# %%
iris.plot(figsize = (16,10))
# Out:
# <AxesSubplot:>

# %%
df  = iris.drop(['species'], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['pclass'].value_counts().sort_index()
# Out:
# 1    216
# 2    184
# 3    491
# Name: pclass, dtype: int64

# %%
titanic['pclass'].value_counts().sort_index().plot.bar()
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3')])

# %%
titanic['survived'].value_counts().sort_index().plot.bar()
plt.xticks(rotation = 0)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
df = pd.DataFrame(randn(10,4), columns = ('a', 'b', 'c', 'd'))

# %%
df
# Out:
#           a         b         c         d
# 0 -1.378178 -0.682170 -0.404703 -0.677133
# 1 -0.204286  0.543586 -0.248965  0.314177
# 2  0.933312 -0.806472 -0.359192  1.433507
# 3  0.912656  1.285672 -1.150926  0.022807
# 4  0.391754 -0.434056 -0.410850 -0.345369
# 5 -0.010836 -0.273720 -1.143282  0.049640
# 6  1.505311 -0.558404 -0.122456  0.968675
# 7 -0.420475  0.679117 -0.180399  0.796910
# 8 -0.140767 -0.893185  0.243240 -0.954695
# 9  1.053815  0.123033 -0.953570 -1.187861

# %%
df.plot.bar(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist(alpha = 0.7)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(bins = 50, stacked = True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist(bins = 30, stacked = True, orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_length'].plot.hist(bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.iloc[:, :-1].hist(figsize = (12,10));

# %%
df.hist(figsize = (12,10))
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>]], dtype=object)

# %%
df.plot(kind = 'box', figsize =  (10,5))
# Out:
# <AxesSubplot:>

# %%
df.plot.box(vert = False)
# Out:
# <AxesSubplot:>

# %%
iris2 = iris.drop('species', axis = 1)

# %%
iris.plot.area(stacked = False)
# Out:
# <AxesSubplot:>

# %%
iris.plot.area(alpha = 0.7)
# Out:
# <AxesSubplot:>

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot.scatter(x = 'sepal_width', y = 'sepal_length')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %%
ax = iris.plot.scatter(x = 'sepal_width', y = 'sepal_length', label = 'sepal')
iris.plot.scatter(x = 'petal_width', y = 'petal_length', ax = ax, color = 'r', label = 'petal')
plt.xlabel('Width')
plt.ylabel('Lenght')
plt.legend()
# Out:
# Text(0, 0.5, 'Lenght')

# %%
iris.plot.hexbin(y = 'sepal_length', x = 'sepal_width', gridsize = 10, C = 'sepal_width');

# %%
iris.iloc[0,:-1]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
iris.iloc[0, :-1].plot.pie()
# Out:
# <AxesSubplot:ylabel='0'>

# %%
a = iris.iloc[:, :-1].head(3).T

# %%
a
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
a.plot.pie(subplots = True, figsize = (30,30), fontsize = 20, autopct = '%.1f');

# %%
s = pd.Series([0.2]*4, index = list('abcd'), name = 'Pie Plot')

# %%
s.plot.pie(normalize=True )
# Out:
# <AxesSubplot:ylabel='Pie Plot'>

# %%
s.to_frame().T.iloc[0].plot.pie()
# Out:
# C:\Users\Hotha\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# <AxesSubplot:ylabel='Pie Plot'>

# %%
s.to_frame().T.iloc[0]
# Out:
# a    0.2
# b    0.2
# c    0.2
# d    0.2
# Name: Pie Plot, dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(iris, figsize = (13,13), diagonal = 'kde', color = 'r', alpha = 1);

# %%
iris.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
iris.plot(subplots = True, figsize = (16,10));

# %%
iris.plot(subplots = True, sharex = False, figsize = (14,10))
plt.tight_layout(pad = 1.2);

# %%
iris.plot(subplots = True, sharex = False, figsize = (14,10), layout = (2,2))
#plt.tight_layout(pad = 1.2);
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)
